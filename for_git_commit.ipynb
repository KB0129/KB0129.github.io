# %% [markdown]
# # Github Commit

# %%
# Google Drive Mount
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# move to folder to connect github
# %cd '/content/drive/MyDrive/Colab Notebooks/kitsune_network_classification'
# Out:
# /content/drive/MyDrive/Colab Notebooks/kitsune_network_classification

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# git
# !git init
# !git config --global user.email 'dlrudqls99@gmail.com'
# !git config --global user.name 'KB0129'
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/kitsune_network_classification/.git/

# %%
# git commit
# !git add .
# !git commit -m "First commit"
# Out:
# warning: adding embedded git repository: kitsune_network_classification
# hint: You've added another git repository inside your current repository.
# hint: Clones of the outer repository will not contain the contents of
# hint: the embedded repository and will not know how to obtain it.
# hint: If you meant to add a submodule, use:
# hint:
# hint: 	git submodule add <url> kitsune_network_classification
# hint:
# hint: If you added this path by mistake, you can remove it from the
# hint: index with:
# hint:
# hint: 	git rm --cached kitsune_network_classification
# hint:
# hint: See "git help submodule" for more information.
# [master a19e7fc] First commit
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  rewrite for_git_commit.ipynb (60%)
#  create mode 160000 kitsune_network_classification

# %%
# github connect
# !git remote add origin https://github.com/KB0129/kitsune_network_classification.git

# %%
# !git add summer_scholar.ipynb

# %%
# !git clone https://github.com/KB0129/kitsune_network_classification.git
# Out:
# Cloning into 'kitsune_network_classification'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), 615 bytes | 8.00 KiB/s, done.

# %%
# git push
# !git commi
# !git push origin master
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
