# %% [markdown]
# # Github Commit

# %%
# Google Drive Mount
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# move to folder to connect github
# %cd '/content/drive/MyDrive/Colab Notebooks/kitsune_network_classification'
# Out:
# [Errno 107] Transport endpoint is not connected: '/content/drive/MyDrive/Colab Notebooks/kitsune_network_classification'
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# git
# !git init
# !git config --global user.email 'dlrudqls99@gmail.com'
# !git config --global user.name 'KB0129'
# Out:
# Initialized empty Git repository in /content/.git/

# %%
# git commit
# !git add .
# !git commit -m "First commit"
# Out:
# error: open("drive/MyDrive/CSUSM/Annotated Bibliography(GEW).gdoc"): Operation not supported
# error: unable to index file 'drive/MyDrive/CSUSM/Annotated Bibliography(GEW).gdoc'
# fatal: adding files failed
# On branch master
#
# Initial commit
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	.config/
# 	drive/
# 	sample_data/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# github connect
# !git remote add origin https://github.com/KB0129/kitsune_network_classification.git

# %%
# !git remote -v
# Out:
# origin	https://github.com/KB0129/kitsune_network_classification.git (fetch)
# origin	https://github.com/KB0129/kitsune_network_classification.git (push)

# %%
# !git remote set-url origin http://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@github.com/KB0129/kitsune_network_classification.git

# %%
# !git pull origin master
# Out:
# ...
# From http://github.com/KB0129/kitsune_network_classification
#  * branch            master     -> FETCH_HEAD
# Already up to date.

# %%
# git push
# !git push https://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@github.com/KB0129/kitsune_network_classification.git
# Out:
# Everything up-to-date
